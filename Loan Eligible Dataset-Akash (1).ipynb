# %% [markdown]
# Problem Statement:
# Dream Housing Finance company deals in all home loans. They have a presence across all urban, semi-urban, and rural areas. Customer-first applies for a home loan after that company validates the customer eligibility for a loan.
#
# The company wants to automate the loan eligibility process (real-time) based on customer detail provided while filling the online application form. These details are Gender, Marital Status, Education, Number of Dependents, Income, Loan Amount, Credit History, and others. To automate this process, they have given a problem to identify the customer's segments, those are eligible for loan amount so that they can specifically target these customers. Here they have provided a partial data set.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report,accuracy_score

# %%
df = pd.read_csv(r'C:\Users\Hp\Downloads\loan-train.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# #### ID COLUMN IF NO USED

# %%
df.drop('Loan_ID',axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %% [markdown]
# #### CONVERTING STRING TO NUMERIC AND REPLACING

# %%
df['Dependents'] = df['Dependents'].replace('3+','3')

# %%
df['Dependents'] = pd.to_numeric(df['Dependents'],errors='coerce').astype(int)

# %%
df
# Out:
#      Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 1      Male     Yes           1      Graduate            No             4583
# 2      Male     Yes           0      Graduate           Yes             3000
# 3      Male     Yes           0  Not Graduate            No             2583
# 4      Male      No           0      Graduate            No             6000
# 5      Male     Yes           2      Graduate           Yes             5417
# ..      ...     ...         ...           ...           ...              ...
# 609  Female      No           0      Graduate            No             2900
# 610    Male     Yes           3      Graduate            No             4106
# 611    Male     Yes           1      Graduate            No             8072
# 612    Male     Yes           2      Graduate            No             7583
# 613  Female      No           0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# 5               4196.0       267.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#     Property_Area Loan_Status
# 1           Rural           N
# 2           Urban           Y
# 3           Urban           Y
# 4           Urban           Y
# 5           Urban           Y
# ..            ...         ...
# 609         Rural           Y
# 610         Rural           Y
# 611         Urban           Y
# 612         Urban           Y
# 613     Semiurban           N
#
# [480 rows x 12 columns]

# %% [markdown]
# #### MANUAL ENCODING

# %%
df['Gender'] = df['Gender'].replace({'Male':1,'Female':0})

# %%
df['Married'] = df['Married'].replace({'Yes':1,'No':0})

# %%
df['Education'] = df['Education'].replace({'Graduate':1,'Not Graduate':0})

# %%
df['Self_Employed'] = df['Self_Employed'].replace({'Yes':1,'No':0})

# %%
df['Property_Area'] = pd.factorize(df['Property_Area']) [0] + 1

# %%
df['Loan_Status'] = df['Loan_Status'].replace({'Y':1,'N':0})

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1           1          1              0             4583
# 2         1        1           0          1              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          1              0             6000
# 5         1        1           2          1              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             2900
# 610       1        1           3          1              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          1              0             7583
# 613       0        0           0          1              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# 5               4196.0       267.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#      Property_Area  Loan_Status
# 1                1            0
# 2                2            1
# 3                2            1
# 4                2            1
# 5                2            1
# ..             ...          ...
# 609              1            1
# 610              1            1
# 611              2            1
# 612              2            1
# 613              3            0
#
# [480 rows x 12 columns]

# %%
df['LoanAmount'] = pd.to_numeric(df['LoanAmount'],errors='coerce').astype(int)

# %%
df['Credit_History'] = pd.to_numeric(df['Credit_History'],errors='coerce').astype(int)

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1           1          1              0             4583
# 2         1        1           0          1              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          1              0             6000
# 5         1        1           2          1              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             2900
# 610       1        1           3          1              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          1              0             7583
# 613       0        0           0          1              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               1508.0         128             360.0               1
# 2                  0.0          66             360.0               1
# 3               2358.0         120             360.0               1
# 4                  0.0         141             360.0               1
# 5               4196.0         267             360.0               1
# ..                 ...         ...               ...             ...
# 609                0.0          71             360.0               1
# 610                0.0          40             180.0               1
# 611              240.0         253             360.0               1
# 612                0.0         187             360.0               1
# 613                0.0         133             360.0               0
#
#      Property_Area  Loan_Status
# 1                1            0
# 2                2            1
# 3                2            1
# 4                2            1
# 5                2            1
# ..             ...          ...
# 609              1            1
# 610              1            1
# 611              2            1
# 612              2            1
# 613              3            0
#
# [480 rows x 12 columns]

# %% [markdown]
# #### MULTIPLYING LAON AMOUNT BY 1000 TO BE A REAL NUMBER

# %%
df['LoanAmount'] = df['LoanAmount']*1000

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1           1          1              0             4583
# 2         1        1           0          1              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          1              0             6000
# 5         1        1           2          1              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             2900
# 610       1        1           3          1              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          1              0             7583
# 613       0        0           0          1              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               1508.0      128000             360.0               1
# 2                  0.0       66000             360.0               1
# 3               2358.0      120000             360.0               1
# 4                  0.0      141000             360.0               1
# 5               4196.0      267000             360.0               1
# ..                 ...         ...               ...             ...
# 609                0.0       71000             360.0               1
# 610                0.0       40000             180.0               1
# 611              240.0      253000             360.0               1
# 612                0.0      187000             360.0               1
# 613                0.0      133000             360.0               0
#
#      Property_Area  Loan_Status
# 1                1            0
# 2                2            1
# 3                2            1
# 4                2            1
# 5                2            1
# ..             ...          ...
# 609              1            1
# 610              1            1
# 611              2            1
# 612              2            1
# 613              3            0
#
# [480 rows x 12 columns]

# %% [markdown]
# #### FINDING OUT THE BEST FEATURES AND REMOVING NON CORELATED FEATURES

# %%
corr = df.corr()

# %%
corr
# Out:
#                      Gender   Married  Dependents  Education  Self_Employed  \
# Gender             1.000000  0.349424    0.217510  -0.059245      -0.002761
# Married            0.349424  1.000000    0.386367  -0.001652       0.015674
# Dependents         0.217510  0.386367    1.000000  -0.028608       0.045754
# Education         -0.059245 -0.001652   -0.028608   1.000000       0.005085
# Self_Employed     -0.002761  0.015674    0.045754   0.005085       1.000000
# ApplicantIncome    0.032644  0.036717    0.131139   0.131172       0.170785
# CoapplicantIncome  0.156171  0.102950   -0.000318   0.074499      -0.001509
# LoanAmount         0.098975  0.183442    0.172780   0.172780       0.120389
# Loan_Amount_Term  -0.088704 -0.107504   -0.096361   0.102168      -0.034852
# Credit_History     0.022447  0.029095   -0.026651   0.056656      -0.023568
# Property_Area     -0.097035  0.028167   -0.030838   0.060010      -0.037900
# Loan_Status        0.064504  0.112321    0.035428   0.068437      -0.034715
#
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Gender                    0.032644           0.156171    0.098975
# Married                   0.036717           0.102950    0.183442
# Dependents                0.131139          -0.000318    0.172780
# Education                 0.131172           0.074499    0.172780
# Self_Employed             0.170785          -0.001509    0.120389
# ApplicantIncome           1.000000          -0.112588    0.495310
# CoapplicantIncome        -0.112588           1.000000    0.190740
# LoanAmount                0.495310           0.190740    1.000000
# Loan_Amount_Term         -0.010838          -0.005775    0.050867
# Credit_History           -0.056152          -0.008692   -0.040773
# Property_Area            -0.024586          -0.004348   -0.039807
# Loan_Status              -0.043152          -0.049020   -0.071753
#
#                    Loan_Amount_Term  Credit_History  Property_Area  \
# Gender                    -0.088704        0.022447      -0.097035
# Married                   -0.107504        0.029095       0.028167
# Dependents                -0.096361       -0.026651      -0.030838
# Education                  0.102168        0.056656       0.060010
# Self_Employed             -0.034852       -0.023568      -0.037900
# ApplicantIncome           -0.010838       -0.056152      -0.024586
# CoapplicantIncome         -0.005775       -0.008692      -0.004348
# LoanAmount                 0.050867       -0.040773      -0.039807
# Loan_Amount_Term           1.000000        0.032937      -0.000568
# Credit_History             0.032937        1.000000       0.040092
# Property_Area             -0.000568        0.040092       1.000000
# Loan_Status               -0.007798        0.529390       0.153843
#
#                    Loan_Status
# Gender                0.064504
# Married               0.112321
# Dependents            0.035428
# Education             0.068437
# Self_Employed        -0.034715
# ApplicantIncome      -0.043152
# CoapplicantIncome    -0.049020
# LoanAmount           -0.071753
# Loan_Amount_Term     -0.007798
# Credit_History        0.529390
# Property_Area         0.153843
# Loan_Status           1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.drop(['Gender','Dependents','Self_Employed','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term'],axis=1,inplace=True)
df
# Out:
#      Married  Education  Credit_History  Property_Area  Loan_Status
# 1          1          1               1              1            0
# 2          1          1               1              2            1
# 3          1          0               1              2            1
# 4          0          1               1              2            1
# 5          1          1               1              2            1
# ..       ...        ...             ...            ...          ...
# 609        0          1               1              1            1
# 610        1          1               1              1            1
# 611        1          1               1              2            1
# 612        1          1               1              2            1
# 613        0          1               0              3            0
#
# [480 rows x 5 columns]

# %%
df.drop('Education',axis=1,inplace=True)
df
# Out:
#      Married  Credit_History  Property_Area  Loan_Status
# 1          1               1              1            0
# 2          1               1              2            1
# 3          1               1              2            1
# 4          0               1              2            1
# 5          1               1              2            1
# ..       ...             ...            ...          ...
# 609        0               1              1            1
# 610        1               1              1            1
# 611        1               1              2            1
# 612        1               1              2            1
# 613        0               0              3            0
#
# [480 rows x 4 columns]

# %%
corr = df.corr()
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### CREDIT HISTORY IMPACT ON LOAN STATUS

# %%
pd.crosstab(df['Credit_History'],df['Loan_Status']).plot(kind='bar')
pd.crosstab(df['Married'],df['Loan_Status']).plot(kind='bar')
pd.crosstab(df['Property_Area'],df['Loan_Status']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Property_Area'>

# %%
df['Loan_Status'].value_counts()
# Out:
# 1    332
# 0    148
# Name: Loan_Status, dtype: int64

# %%
df['Loan_Status'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='Loan_Status'>

# %% [markdown]
# #### IMBALANCED HANDLING

# %%
pip install imbalanced-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imbalanced-learn in c:\users\hp\appdata\roaming\python\python39\site-packages (0.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hp\appdata\roaming\python\python39\site-packages (from imbalanced-learn) (1.3.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (1.21.5)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
X = df.drop(["Loan_Status"], axis=1)
y = df['Loan_Status']

smote = SMOTE(random_state=42)

Xr, yr = smote.fit_resample(X, y)

# %%
pd.crosstab(df['Credit_History'],yr).plot(kind='bar')
pd.crosstab(df['Married'],yr).plot(kind='bar')
pd.crosstab(df['Property_Area'],yr).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Property_Area'>

# %%
Xr.head()
# Out:
#    Married  Credit_History  Property_Area
# 0        1               1              1
# 1        1               1              2
# 2        1               1              2
# 3        0               1              2
# 4        1               1              2

# %% [markdown]
# #### SPLIT THE DATA

# %%
X_train,X_test,y_train,y_test = train_test_split(Xr,yr,test_size=0.30,random_state=1)

# %%
logreg = LogisticRegression()
knn = KNeighborsClassifier()
dt = DecisionTreeClassifier()
svm = SVC()

# %%
def mymodel(model):
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    print(classification_report(y_test,y_pred))
    print('Accuracy Score :',accuracy_score(y_test,y_pred))
    
    train = model.score(X_train,y_train)
    test = model.score(X_test,y_test)
    
    print('Training Performance',train)
    print('Testing Performnace',test)
    
    return model

# %%
mymodel(logreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.56      0.65        97
#            1       0.67      0.84      0.75       103
#
#     accuracy                           0.70       200
#    macro avg       0.72      0.70      0.70       200
# weighted avg       0.72      0.70      0.70       200
#
# Accuracy Score : 0.705
# Training Performance 0.7068965517241379
# Testing Performnace 0.705
# LogisticRegression()

# %%
mymodel(knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.66      0.65        97
#            1       0.67      0.66      0.67       103
#
#     accuracy                           0.66       200
#    macro avg       0.66      0.66      0.66       200
# weighted avg       0.66      0.66      0.66       200
#
# Accuracy Score : 0.66
# Training Performance 0.7047413793103449
# Testing Performnace 0.66
# KNeighborsClassifier()

# %%
mymodel(dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.52      0.62        97
#            1       0.65      0.86      0.74       103
#
#     accuracy                           0.69       200
#    macro avg       0.72      0.69      0.68       200
# weighted avg       0.72      0.69      0.68       200
#
# Accuracy Score : 0.695
# Training Performance 0.7241379310344828
# Testing Performnace 0.695
# DecisionTreeClassifier()

# %%
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.63      0.67        97
#            1       0.68      0.76      0.72       103
#
#     accuracy                           0.69       200
#    macro avg       0.70      0.69      0.69       200
# weighted avg       0.70      0.69      0.69       200
#
# Accuracy Score : 0.695
# Training Performance 0.7219827586206896
# Testing Performnace 0.695
# SVC()

# %%
pip install Xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Xgboost in c:\users\hp\appdata\roaming\python\python39\site-packages (1.7.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from Xgboost) (1.9.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from Xgboost) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier

# %%
xg = XGBClassifier()
xg.fit(X_train,y_train)
y_pred = xg.predict(X_test)
print(classification_report(y_test,y_pred))
print('Accuracy Score ',accuracy_score(y_test,y_pred))

train = xg.score(X_train,y_train)
test = xg.score(X_test,y_test)
    
print('Training Performance',train)
print('Testing Performnace',test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.52      0.62        97
#            1       0.65      0.86      0.74       103
#
#     accuracy                           0.69       200
#    macro avg       0.72      0.69      0.68       200
# weighted avg       0.72      0.69      0.68       200
#
# Accuracy Score  0.695
# Training Performance 0.7241379310344828
# Testing Performnace 0.695

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
print(classification_report(y_test,y_pred))
print('Accuracy Score : ',accuracy_score(y_test,y_pred))

train = rf.score(X_train,y_train)
test = rf.score(X_test,y_test)
    
print('Training Performance',train)
print('Testing Performnace',test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.52      0.62        97
#            1       0.65      0.86      0.74       103
#
#     accuracy                           0.69       200
#    macro avg       0.72      0.69      0.68       200
# weighted avg       0.72      0.69      0.68       200
#
# Accuracy Score :  0.695
# Training Performance 0.7241379310344828
# Testing Performnace 0.695

# %%
df['Credit_History'].value_counts()
# Out:
# 1    410
# 0     70
# Name: Credit_History, dtype: int64

# %%
Xr
# Out:
#      Married  Credit_History  Property_Area
# 0          1               1              1
# 1          1               1              2
# 2          1               1              2
# 3          0               1              2
# 4          1               1              2
# ..       ...             ...            ...
# 659        0               1              3
# 660        0               1              3
# 661        0               1              1
# 662        0               1              3
# 663        0               1              3
#
# [664 rows x 3 columns]

# %%
def loanpred():
    married = eval(input('if you are married enter 1 and if not enter 0 :'))
    credit_history = eval(input('if your credit history is good enter 1 and if bad enter 0 : '))
    property_area = eval(input('if you want in rural enter 1, if you want in urban press 2, if you want in semiurban press 3 : '))
    
    newob =[[married,credit_history,property_area]]
    yp = rf.predict(newob)[0]
    print('if the digit is 1 you can get a loan')
    print('if a digit is 0 you cannot get a loan')
    print('your answer is',yp)

# %%
loanpred()
# Out:
# if you are married enter 1 and if not enter 0 :0
# if your credit history is good enter 1 and if bad enter 0 : 1
# if you want in rural enter 1, if you want in urban press 2, if you want in semiurban press 3 : 2
# if the digit is 1 you can get a loan
# if a digit is 0 you cannot get a loan
# your answer is 0

# %%
loanpred()

# %%
loanpred()

# %%
loanpred()

# %%
loanpred()

# %%
loanpred()
